# %% [markdown]
# AUTOMAÇÃO DE SISTEMAS E PROCESSOS COM PYTHON

# %%
# importar as bibliotecas
import pyautogui # faz a automação do mouse e do teclado
from time import sleep
import pyperclip # permite copiar e colar com o python
import pandas as pd

pyautogui.PAUSE = 1
pyautogui.alert('Iniciando a automação, não mecha no teclado e no mouse', 'Automação de Analise')

# Passo 1: Entrar no sistema (pasta do google drive)
pyautogui.hotkey('ctrl', 't')

# podemos entrar na pasta de duas maneira
# 1: Mandando o python escrever o endereço que vamos acessar
# pyautogui.write('https://drive.google.com/drive/u/0/folders/11gwpLj_Hx_Pdx1zWG2hVxr-Tcwk-H2j9')
# 2: Mandando o python copiar e colar o link
link = 'https://drive.google.com/drive/u/0/folders/11gwpLj_Hx_Pdx1zWG2hVxr-Tcwk-H2j9'
# copia o link
pyperclip.copy(link) # permite copiar o conteúdo de uma variavel
#cola o link
pyautogui.hotkey('ctrl', 'v')

pyautogui.press('enter') #clicar a tecla enter
sleep(5)

# Passo 2: Entrar na pasta da Aula 1

# Passo 3: Fazer o download da base de vendas
pyautogui.click(382,379)
pyautogui.click(1713,156)
pyautogui.click(1517,594)
sleep(10)

# Passo 4: Calcular os indicadores
tabela = pd.read_excel(r'D:\clientes\pessoal\estudo\semana python\Vendas - Dez.xlsx', sheet_name=0) #sheet_name é um parametro opcional para passar a posição da planilha
display(tabela)
faturamento = tabela['Valor Final'].sum()
qtde_produtos = tabela['Quantidade'].sum()
print(f'Faturamento: {faturamento} \nQuantidade de produtos: {qtde_produtos}')

# Passo 5: Entrar no meu email
# Passo 6: Criar o emil
# Passo 7: Enviar o email

# %%
import pyautogui # faz a automação do mouse e do teclado
from time import sleep
import pyperclip # permite copiar e colar com o python

pyautogui.hotkey('ctrl', 't')
linkemail = 'https://mail.google.com'
pyperclip.copy(linkemail)
pyautogui.hotkey('ctrl', 'v')
pyautogui.press('enter')
sleep(8)

# tratar caracter especial
# Como o pyautogui não trabalha com caracteres especiais
# é melhor trabalhar com o pyperclip copiando o texto de uma variavel

# usar 3 aspas duplas deixa o texto pré formatado
texto_email = """
Prezados, bom dia!

O faturamento foi de: x
A quantidade de produtos vendidos foi de:

"""

# %%
import pandas as pd
tabela = pd.read_excel(r'D:\clientes\pessoal\estudo\semana python\Vendas - Dez.xlsx', sheet_name=0) #sheet_name é um parametro opcional para passar a posição da planilha
display(tabela)
faturamento = tabela['Valor Final'].sum()
qtde_produtos = tabela['Quantidade'].sum()
print(f'Faturamento: {faturamento} \nQuantidade de produtos: {qtde_produtos}')
# Out:
#       Código Venda       Data                     ID Loja           Produto  \
# 0            65014 2019-12-01            Shopping Morumbi    Sunga Listrado
# 1            65014 2019-12-01            Shopping Morumbi   Casaco Listrado
# 2            65016 2019-12-01           Iguatemi Campinas   Sapato Listrado
# 3            65016 2019-12-01           Iguatemi Campinas            Casaco
# 4            65017 2019-12-01          Shopping SP Market        Gorro Liso
# ...            ...        ...                         ...               ...
# 7084         69996 2019-12-26  Center Shopping Uberlândia    Short Listrado
# 7085         69996 2019-12-26  Center Shopping Uberlândia           Mochila
# 7086         69996 2019-12-26  Center Shopping Uberlândia  Pulseira Estampa
# 7087         69997 2019-12-26           Ribeirão Shopping   Camisa Listrado
# 7088         69997 2019-12-26           Ribeirão Shopping       Short Linho
#
#       Quantidade  Valor Unitário  Valor Final
# ...

# %%
# Podemos fazer com a função sleep para posicionar o mouse no local
sleep(5)
pyautogui.position()

# pyautogui.click('1516', '509', clicks=2)
# Out:
# Point(x=1517, y=594)
